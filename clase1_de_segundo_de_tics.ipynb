# %% [markdown]
# <a href="https://colab.research.google.com/github/tarcosarahi26-rgb/hola-mundo/blob/master/clase1_de_segundo_de_tics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##LENGUAJE C++
#
# el lenguaje de programaciòn de c++ es uno de los mas potentes y utiizados en el mundo ya que utiliza la combinacion de la eficiencia del lenguaje c y su orientacion a objetos lo que permite creacion de un software de alto rendimiento.

# %%
#include <stdio.h>
int main(void) {
    printfa("hello world")
    return 0;
}
# Out:
#   File "/tmp/ipykernel_1589/1849659837.py", line 2
#     int main(void) {
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# JAVA SCRIPT
# es un leguaje de programacion que se utiliza principalmente para crear paginas dinamicas.

# %%
console.log("hello wordl")

# %% [markdown]
# PYTHON
# lenguaje de programcion orientada a objetos

# %%
print("hola mundo")
